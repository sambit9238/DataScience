# %%
#import all dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#ignoring warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#import data
df = pd.read_csv("World_trend_survey.csv")

# %%
df.head()
# Out:
#    Unnamed: 0          Country Name Country Code  Birth rate  Internet users  \
# 0           0                 Aruba          ABW      10.244            78.9
# 1           1           Afghanistan          AFG      35.253             5.9
# 2           2                Angola          AGO      45.985            19.1
# 3           3               Albania          ALB      12.877            57.2
# 4           4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group Country Region  LifeExp1960  LifeExp2013
# 0          High income   The Americas    65.569366    75.328659
# 1           Low income           Asia    32.328512    60.028268
# 2  Upper middle income         Africa    32.984829    51.866171
# 3  Upper middle income         Europe    62.254366    77.537244
# 4          High income    Middle East    52.243220    77.195634

# %%
#distribution
vis1 = sns.distplot(df["Internet users"],bins=10)

# %%
#box plot
vis2 = sns.boxplot(data = df, x = "Income Group", y = "Birth rate")
fig = vis2.get_figure()
fig.savefig("sb6.png")

# %%
vis3 = sns.boxplot(data = df, x = "Income Group", y = "Internet users")

# %%
vis4 = sns.boxplot(data = df, x = "Country Region", y = "Internet users")

# %%
vis5 = sns.boxplot(data = df, x = "Country Region", y = "Birth rate")

# %%
vis6 = sns.lmplot(data = df, x = "Internet users", y = "Birth rate",fit_reg=False)
#fig = vis6.get_figure()
vis6.savefig("sb6.png")

# %%
vis7 = sns.lmplot(data = df, x = "Internet users", y = "Birth rate",fit_reg=False, hue = "Income Group",\
                 size = 6, aspect=1.5, scatter_kws = {'s':200}, )
vis7.savefig("sb7.png")

# %%
vis8= sns.lmplot(data = df, x = "Internet users", y = "Birth rate",fit_reg=False,\
                  hue = "Country Region",\
                 size = 6, aspect=1.5, scatter_kws = {'s':200}, )
vis8.savefig("sb8.png")
