# %%
#numpy and pandas will be used for various data operation
import numpy as np
import pandas as pd

# %%
#creating data frames
df = pd.DataFrame()
name = ["sambit", "jack", "william", "raj"]
age = [20, 23, 42, 12]
hobby = ["song", "dance", "cricket", "football"]
df["name"] = name
df["age"] = age
df["hobby"] = hobby
df.head()
# Out:
#       name  age     hobby
# 0   sambit   20      song
# 1     jack   23     dance
# 2  william   42   cricket
# 3      raj   12  football

# %%
#reading the data from local file to a data frame
df = pd.read_csv("DS-skills-DFE.csv", delimiter=",")
# for excel read_excel function is there, in read_csv we can change the delimiter by setting the 
#parameter delimiter if required

# %%
#displaying data frame

# %%
df.head()
# Out:
#   post_yn cloud_software_required database_software_required  \
# 0     yes                    Hive                        SQL
# 1     yes                     NaN                        SQL
# 2     yes                   NoSQL                        SQL
# 3     yes                   NoSQL                        SQL
# 4     yes                     Pig                        NaN
#
#   statistic_software_required programming_language_required  \
# 0                           R                        Python
# 1                         NaN                        Python
# 2                         NaN                        Python
# 3                        SPSS                        Python
# 4                           R                        Python
#
#                                         linkedin_url
# 0  https://www.linkedin.com/jobs2/view/26909460?t...
# 1  https://www.linkedin.com/jobs2/view/18721409?t...
# 2  https://www.linkedin.com/jobs2/view/13715592?t...
# ...

# %%
df.tail()
# Out:
#     post_yn cloud_software_required database_software_required  \
# 969     yes                     NaN                   Teradata
# 970     yes                     Pig                      mySQL
# 971     yes                     NaN                   Teradata
# 972     yes                     Pig                        SQL
# 973     yes                   NoSQL                        SQL
#
#     statistic_software_required programming_language_required  \
# 969                           R                           NaN
# 970                         SAS          C/C++/C#/Objective-C
# 971                         SAS                           NaN
# 972                           R                        Python
# 973                           R          C/C++/C#/Objective-C
#
#                                           linkedin_url
# 969  https://www.linkedin.com/jobs2/view/25814237?t...
# 970  https://www.linkedin.com/jobs2/view/18494958?t...
# ...

# %%
df.sample(5) #it will show 5 randomly selected rows fo the data frame
# Out:
#     post_yn cloud_software_required database_software_required  \
# 622     yes                     NaN                        SQL
# 771     yes                     NaN                        NaN
# 146     yes                     NaN                        SQL
# 731     yes                     NaN                        NaN
# 154     yes                    Hive                        SQL
#
#     statistic_software_required programming_language_required  \
# 622                         SAS                           NaN
# 771                         NaN                           NaN
# 146                        SPSS                        Python
# 731                         NaN                           NaN
# 154                       STATA                        Python
#
#                                           linkedin_url
# 622  https://www.linkedin.com/jobs2/view/18942076?t...
# 771  https://www.linkedin.com/jobs2/view/18787963?t...
# ...

# %%
#attribute informations
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 6 columns):
# post_yn    974 non-null object
# cloudsw    406 non-null object
# dbsw       564 non-null object
# statsw     496 non-null object
# prog       526 non-null object
# url        974 non-null object
# dtypes: object(6)
# memory usage: 45.7+ KB

# %%
#statistical summary of data
df.describe()
# Out:
#        post_yn cloudsw dbsw statsw    prog  \
# count      974     406  564    496     526
# unique       1       5    5      5       6
# top        yes     Pig  SQL      R  Python
# freq       974     123  488    194     367
#
#                                                       url
# count                                                 974
# unique                                                936
# top     https://www.linkedin.com/jobs2/view/26900269?t...
# freq                                                    3

# %% [raw]
# # Slicing data frame can be in 3 ways:
# 1. rows
# 2. columns
# 3. combinr the two

# %%
#row wise subsetting
df[2:6] # show from 2nd row to 6-1 = 5th row of the data frame
# Out:
#   post_yn cloud_software_required database_software_required  \
# 2     yes                   NoSQL                        SQL
# 3     yes                   NoSQL                        SQL
# 4     yes                     Pig                        NaN
# 5     yes                   NoSQL                        SQL
#
#   statistic_software_required programming_language_required  \
# 2                         NaN                        Python
# 3                        SPSS                        Python
# 4                           R                        Python
# 5                        SPSS                        Python
#
#                                         linkedin_url
# 2  https://www.linkedin.com/jobs2/view/13715592?t...
# 3  https://www.linkedin.com/jobs2/view/13529837?t...
# 4  https://www.linkedin.com/jobs2/view/38267683?t...
# 5  https://www.linkedin.com/jobs2/view/25884513?t...

# %%
#reverse the dataframe
df[::-1]
# Out:
#     post_yn      cloud_software_required database_software_required  \
# 973     yes                        NoSQL                        SQL
# 972     yes                          Pig                        SQL
# 971     yes                          NaN                   Teradata
# 970     yes                          Pig                      mySQL
# 969     yes                          NaN                   Teradata
# 968     yes  MapReduce/Elastic MapReduce                        NaN
# 967     yes                          NaN                      mySQL
# 966     yes                          NaN                        SQL
# 965     yes                          NaN                        NaN
# 964     yes                          NaN                        NaN
# 963     yes                          Pig                        NaN
# 962     yes                          NaN                        NaN
# 961     yes                          NaN                        SQL
# ...

# %%
#get only every 20th rows
df[::20]
# Out:
#     post_yn      cloud_software_required database_software_required  \
# 0       yes                         Hive                        SQL
# 20      yes                          NaN                        SQL
# 40      yes  MapReduce/Elastic MapReduce                        NaN
# 60      yes                          Pig                        SQL
# 80      yes                        NoSQL                        SQL
# 100     yes                       Hadoop                        NaN
# 120     yes                       Hadoop                        NaN
# 140     yes                       Hadoop                        SQL
# 160     yes  MapReduce/Elastic MapReduce                        SQL
# 180     yes                          NaN                        SQL
# 200     yes                          Pig                        SQL
# 220     yes                          NaN                        SQL
# 240     yes                          Pig                        NaN
# ...

# %%
#column wise subset
df.columns
# Out:
# Index(['post_yn', 'cloud_software_required', 'database_software_required',
#        'statistic_software_required', 'programming_language_required',
#        'linkedin_url'],
#       dtype='object')

# %%
df['cloud_software_required'].head()
# Out:
# 0     Hive
# 1      NaN
# 2    NoSQL
# 3    NoSQL
# 4      Pig
# Name: cloud_software_required, dtype: object

# %%
df[['cloud_software_required','database_software_required']].head()
# Out:
#   cloud_software_required database_software_required
# 0                    Hive                        SQL
# 1                     NaN                        SQL
# 2                   NoSQL                        SQL
# 3                   NoSQL                        SQL
# 4                     Pig                        NaN

# %%
#row and column subsetting combined
df[2:5][['cloud_software_required','programming_language_required']] 
#it will first select rows 2 to 4 and then filter out mentioned columns only
# Out:
#   cloud_software_required programming_language_required
# 2                   NoSQL                        Python
# 3                   NoSQL                        Python
# 4                     Pig                        Python

# %%
df[['cloud_software_required','programming_language_required']][2:5]
#it will first select the mentioned columns and then filter out rows 2 to 4 only
# Out:
#   cloud_software_required programming_language_required
# 2                   NoSQL                        Python
# 3                   NoSQL                        Python
# 4                     Pig                        Python

# %%
#add columns 
df["statistic_software_and_language_required"] = df["statistic_software_required"]+" and "+df["programming_language_required"]

# %%
df.head()
# Out:
#   post_yn cloud_software_required database_software_required  \
# 0     yes                    Hive                        SQL
# 1     yes                     NaN                        SQL
# 2     yes                   NoSQL                        SQL
# 3     yes                   NoSQL                        SQL
# 4     yes                     Pig                        NaN
#
#   statistic_software_required programming_language_required  \
# 0                           R                        Python
# 1                         NaN                        Python
# 2                         NaN                        Python
# 3                        SPSS                        Python
# 4                           R                        Python
#
#                                         linkedin_url  \
# 0  https://www.linkedin.com/jobs2/view/26909460?t...
# 1  https://www.linkedin.com/jobs2/view/18721409?t...
# 2  https://www.linkedin.com/jobs2/view/13715592?t...
# ...

# %%
#drop a column
df.drop("statistic_software_and_language_required", axis=1, inplace=True) #axis 1 for column and 0 for row
#by default drop functin remove rows

# %%
df.head()
# Out:
#   post_yn cloud_software_required database_software_required  \
# 0     yes                    Hive                        SQL
# 1     yes                     NaN                        SQL
# 2     yes                   NoSQL                        SQL
# 3     yes                   NoSQL                        SQL
# 4     yes                     Pig                        NaN
#
#   statistic_software_required programming_language_required  \
# 0                           R                        Python
# 1                         NaN                        Python
# 2                         NaN                        Python
# 3                        SPSS                        Python
# 4                           R                        Python
#
#                                         linkedin_url
# 0  https://www.linkedin.com/jobs2/view/26909460?t...
# 1  https://www.linkedin.com/jobs2/view/18721409?t...
# 2  https://www.linkedin.com/jobs2/view/13715592?t...
# ...

# %%
##changing column names (in data column names might be very big and inconvenient to use)
df.columns = ["post_yn", "cloudsw", "dbsw", "statsw", "prog", "url"]

# %%
##filtering
##row filter
df.prog == "Python"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7      False
# 8       True
# 9       True
# 10      True
# 11      True
# 12     False
# 13     False
# 14      True
# 15      True
# 16     False
# 17      True
# 18     False
# 19     False
# 20      True
# 21     False
# 22      True
# 23     False
# 24      True
# 25     False
# 26      True
# 27      True
# 28     False
# 29     False
#        ...
# 944     True
# 945    False
# 946     True
# 947    False
# 948    False
# 949     True
# 950     True
# 951    False
# 952    False
# 953     True
# 954     True
# 955    False
# 956    False
# 957     True
# 958    False
# 959    False
# 960    False
# 961     True
# 962    False
# 963    False
# 964     True
# 965     True
# 966     True
# 967     True
# 968    False
# 969    False
# 970    False
# 971    False
# 972     True
# 973    False
# Name: prog, dtype: bool

# %%
#we want to those data rows where programming language is Python and database requirement SQL
df1 = df[(df.prog == "Python") & (df.dbsw == "SQL")]
df1.head()
# Out:
#   post_yn cloudsw dbsw statsw    prog  \
# 0     yes    Hive  SQL      R  Python
# 1     yes     NaN  SQL    NaN  Python
# 2     yes   NoSQL  SQL    NaN  Python
# 3     yes   NoSQL  SQL   SPSS  Python
# 5     yes   NoSQL  SQL   SPSS  Python
#
#                                                  url
# 0  https://www.linkedin.com/jobs2/view/26909460?t...
# 1  https://www.linkedin.com/jobs2/view/18721409?t...
# 2  https://www.linkedin.com/jobs2/view/13715592?t...
# 3  https://www.linkedin.com/jobs2/view/13529837?t...
# 5  https://www.linkedin.com/jobs2/view/25884513?t...

# %%
#get unique values in an attribute
df.prog.unique()
# Out:
# array(['Python', nan, 'Ruby', 'Java/Javascript', 'C/C++/C#/Objective-C',
#        'HTML/HTML5', 'Perl'], dtype=object)

# %%
##accessing particular elements
df.iat[2,4] #2nd row and 4th column
# Out:
# 'Python'

# %%
df.iloc[2,4] #2nd row and 4th column
# Out:
# 'Python'

# %%
df.iloc[2] #row 2
# Out:
# post_yn                                                  yes
# cloudsw                                                NoSQL
# dbsw                                                     SQL
# statsw                                                   NaN
# prog                                                  Python
# url        https://www.linkedin.com/jobs2/view/13715592?t...
# Name: 2, dtype: object

# %%
#.at can also be used to acess elements
df.at[0,'prog'] #instead of column number column name is provided
# Out:
# 'Python'

# %%
df.loc[0,"prog"]
# Out:
# 'Python'

# %%
df.loc[:,'prog'] #column named 'prog' is selected
# Out:
# 0                    Python
# 1                    Python
# 2                    Python
# 3                    Python
# 4                    Python
# 5                    Python
# 6                    Python
# 7                       NaN
# 8                    Python
# 9                    Python
# 10                   Python
# 11                   Python
# 12                      NaN
# 13                      NaN
# 14                   Python
# 15                   Python
# 16                      NaN
# 17                   Python
# 18                     Ruby
# 19                      NaN
# 20                   Python
# 21                      NaN
# 22                   Python
# 23                      NaN
# 24                   Python
# 25          Java/Javascript
# 26                   Python
# 27                   Python
# 28                      NaN
# 29                     Ruby
#                ...
# 944                  Python
# 945                     NaN
# ...

# %%
#saving to local file
df.to_csv("output.csv")
