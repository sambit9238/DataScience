# %%
#importing the required modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %% [raw]
# The dataset contains 150 observations of iris flowers. There are four columns of measurements of the flowers in centimeters. The fifth column is the species of the flower observed. All observed flowers belong to one of three species.
# https://en.wikipedia.org/wiki/Iris_flower_data_set

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
df= pd.read_csv(url,names=names)

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# In this step we are going to take a look at the data a few different ways:
#
#     Dimensions of the dataset.
#     Peek at the data itself.
#     Statistical summary of all attributes.
#     Breakdown of the data by the class variable.

# %%
#dimension of the data
df.shape
# Out:
# (150, 5)

# %%
df.head(4) #to show first 4 rows of the data frame
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa

# %%
df.tail(4) #to show last 4 rows of the data frame
# Out:
#      sepal-length  sepal-width  petal-length  petal-width           class
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.sample(5) #to show 5 random samples from the dataframe
# Out:
#      sepal-length  sepal-width  petal-length  petal-width           class
# 39            5.1          3.4           1.5          0.2     Iris-setosa
# 106           4.9          2.5           4.5          1.7  Iris-virginica
# 128           6.4          2.8           5.6          2.1  Iris-virginica
# 29            4.7          3.2           1.6          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa

# %%
df.info() #to get the inforamation about the data in each attribute
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal-length    150 non-null float64
# sepal-width     150 non-null float64
# petal-length    150 non-null float64
# petal-width     150 non-null float64
# class           150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df.describe()# to get statistical informations about each attribute
# Out:
#        sepal-length  sepal-width  petal-length  petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#now have to look at the class distribution
from collections import Counter
Counter(df["class"])
# Out:
# Counter({'Iris-setosa': 50, 'Iris-versicolor': 50, 'Iris-virginica': 50})

# %% [raw]
# We now have a basic idea about the data. We need to extend that with some more visualizations.
#
# We are going to look at two types of plots:
#
# Univariate plots to better understand each attribute.
# Multivariate plots to better understand the relationships between attributes.

# %%
# box and whisker plots
df.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
plt.show()

# %%
df.hist()
plt.show()

# %%
# scatter plot matrix
from pandas.tools.plotting import scatter_matrix
scatter_matrix(df)
plt.show()

# %%
plt.plot(df["sepal-length"], color="black", ls="-", marker="o", ms=0) 
plt.plot(df["sepal-width"], color="blue", ls="-", marker="o", ms=0)
#ls means line of sight and ms means marker size
plt.show()

# %%
plt.plot(df["petal-length"], color="black", ls="-", marker="o", ms=0) 
plt.plot(df["petal-width"], color="blue", ls="-", marker="o", ms=0)
#ls means line of sight and ms means marker size
plt.show()

# %%
plt.plot(df["sepal-length"], color="black", ls="-", marker="o", ms=0) 
plt.plot(df["petal-length"], color="blue", ls="-", marker="o", ms=0)
#ls means line of sight and ms means marker size
plt.show()

# %%
plt.plot(df["sepal-width"], color="black", ls="-", marker="o", ms=0) 
plt.plot(df["petal-width"], color="blue", ls="-", marker="o", ms=0)
#ls means line of sight and ms means marker size
plt.show()
